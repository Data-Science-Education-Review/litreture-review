# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import re
import requests
import json
import time

# %% [markdown]
# # Load data

# %%
# Read raw queries file
row_queries = pd.read_excel('https://docs.google.com/uc?id=13-a2B6RNmUQOFAsJ0vLZISuPZNRSXiz-')

print ('Number of raw items:',row_queries.shape[0])

row_queries.head()
# Out:
# Number of raw items: 33716
#    Unnamed: 0            source  \
# 0           0  semantic scholar
# 1           1  semantic scholar
# 2           2  semantic scholar
# 3           3  semantic scholar
# 4           4  semantic scholar
#
#                                                title  \
# 0  LEADING the Way: A New Model for Data Science ...
# 1  Re-Shape: A Method to Teach Data Ethics for Da...
# 2     The Role of Academia in Data Science Education
# 3    Data Science Education: Curriculum and pedagogy
# 4  Introducing GAISE II: A Guideline for Precolle...
#
#                                             abstract  doi  \
# 0  Addressing the data skills gap, namely the sup...  NaN
# 1  Data has become central to the technologies an...  NaN
# 2  As the demand for data scientists continues to...  NaN
# 3  Data science is a new field of research focuse...  NaN
# 4  Column Editorâ€™s note: In this column Anna Ba...  NaN
#
#                                     paperId
# 0  b1452907e85f6e4d315ca8c61a1393403a533b2f
# 1  4b4fdc82593e3c59a8f18fb7ab4e06ece0af3cf6
# 2  41cf91ee13a1d15983ede066ddf6b67cc94a41f4
# 3  5d090dbeae225383d56ee7ac17b611adeb21c3e3
# 4  92a7cd8186400b382463dea25b2c0797cac8fbd5

# %% [markdown]
# # Pre process raw queries file
#
# The five sources of academic databases used in this research have different information per paper, for example DOI is given only by ACM and IEEE, and not by Web of Science and Google scholar, therefore, it is not possible to search based on a single identifier. As most papers do not have DOI, we use title search. Titles also vary between sources, for example different capitalization style, or using - instead of :. Therefore, we remove any non alphabetic characters from the title and convert all characters to lowercase.

# %%
row_queries['title'] = row_queries['title'].str.lower()
row_queries['title'] = row_queries['title'].str.replace('&amp;','')
row_queries['title'] = row_queries['title'].str.replace('[^ 0-9a-zA-Z]','',regex=True)
row_queries['title'] = row_queries['title'].str.replace(' +',' ',regex=True)

# %% [markdown]
# Drop duplicated papers

# %%
row_queries.drop_duplicates('title',inplace=True)

print ('Number of unique raw items:',row_queries.shape[0])
# Out:
# Number of unique raw items: 31758

# %% [markdown]
# # Search papers in Semantic Scholar

# %%
Semantic_scholar_API_key = '' #Put your API KEY here

if Semantic_scholar_API_key:
  headers={"x-api-key":Semantic_scholar_API_key}
else:
  headers={}

# %% [markdown]
# Find matching Semantic scholar papre ID for papers from the other sources

# %%
for i in row_queries[row_queries['paperId'].isna()].index:

  title = row_queries.loc[i,'title']

  # get matching documants from Semantic Scholar
  response = requests.get('https://api.semanticscholar.org/graph/v1/paper/search?query='+title+'&limit=10&fields=title,abstract',headers=headers)
  response_dict = json.loads(response.text)

  if 'data' not in response_dict:
    continue

  # match all papers in the response
  title_stem = re.sub('[^a-zA-Z]','',title).lower()

  for candidate in response_dict['data']:
    candidate_title_stem = re.sub('[^a-zA-Z]','',candidate['title']).lower()

    if candidate_title_stem == title_stem:
      row_queries.loc[i,'paperId'] = candidate['paperId']
      row_queries.loc[i,'abstract'] = candidate['abstract']
      print(i,'found:',title)
      break

    # If exact mach was not found, search for 95% correlation between the paper title and acandidate title
    elif (candidate['title'].count(' ')>4) and (title.count(' ')>4) and len(candidate_title_stem)>5 and len(title_stem)>5:
      (s1,s2) = (candidate_title_stem,title_stem) if len(candidate_title_stem)>len(title_stem) else (title_stem,candidate_title_stem)
      s1=' '*(len(s2)//5)+s1+' '*(len(s2)//5)
      corr = max([sum([c1==c2 for (c1,c2) in zip(s1[i:i+len(s2)],s2)])/len(s2) for i in range(len(s1)+2*len(s2)//5)])
      if corr>0.95:
        row_queries.loc[i,'paperId'] = candidate['paperId']
        row_queries.loc[i,'abstract'] = candidate['abstract']
        print(i,'found:',title)
        break

    else:
      print(i,'missing:',title)

  time.sleep(.1)
# Out:
# 30086 found
# 30087 found
# 30092 found
# 30098 found
# 30102 found
# 30110 found
# 30111 found
# 30112 found
# 30114 found
# 30119 found
# 30121 found
# 30122 found
# 30123 found
# 30124 found
# 30127 found
# 30129 found
# 30130 found
# 30131 found
# 30133 found
# 30134 found
# 30137 found
# 30140 found
# 30145 found
# 30146 found
# 30147 found
# 30149 found
# 30150 found
# 30151 found
# 30155 found
# 30157 found
# 30159 found
# 30160 found
# 30163 found
# 30165 found
# 30166 found
# 30167 found
# 30170 found
# 30172 found
# 30174 found
# 30175 found
# 30176 found
# 30179 found
# 30180 found
# 30182 found
# 30186 found
# 30187 found
# 30188 found
# 30189 found
# 30190 found
# 30194 found
# 30197 found
# 30200 found
# 30201 found
# 30202 found
# 30204 found
# 30205 found
# 30206 found
# 30208 found
# 30211 found
# 30215 found
# 30216 found
# 30218 found
# 30219 found
# 30222 found 1.0 big data business technology education and science big data ubiquity symposium - Big Data: Business, Technology, Education, and Science
# 30224 found
# 30227 found
# 30228 found
# 30229 found
# 30230 found
# 30232 found
# 30234 found
# 30235 found
# 30236 found
# 30237 found
# 30242 found
# 30243 found
# 30244 found
# 30245 found
# 30248 found
# 30249 found
# 30251 found
# 30252 found
# 30257 found
# 30258 found
# 30262 found
# 30263 found
# 30264 found
# 30267 found
# 30268 found
# 30270 found
# 30271 found
# 30272 found
# 30275 found
# 30282 found
# 30283 found
# 30286 found
# 30287 found
# 30289 found
# 30290 found
# 30291 found
# 30292 found
# 30294 found
# 30295 found
# 30296 found
# 30297 found
# 30299 found
# 30301 found
# 30303 found
# 30304 found
# 30305 found
# 30307 found
# 30308 found
# 30309 found
# 30310 found
# 30312 found
# 30313 found
# 30314 found
# 30315 found
# 30316 found
# 30318 found
# 30319 found
# 30321 found
# 30322 found
# 30323 found
# 30324 found
# 30325 found
# 30326 found
# 30327 found
# 30329 found
# 30330 found
# 30332 found
# 30333 found
# 30334 found
# 30335 found
# 30336 found
# 30337 found
# 30339 found
# 30340 found
# 30342 found
# 30343 found
# 30344 found
# 30345 found
# 30346 found
# 30347 found
# 30348 found
# 30350 found
# 30351 found
# 30353 found
# 30355 found
# 30356 found
# 30358 found
# 30361 found
# 30363 found
# 30364 found
# 30365 found
# 30367 found
# 30368 found 1.0 iwspa 18 proceedings of the fourth acm international workshop on security and privacy analytics - Proceedings of the Fourth ACM International Workshop on Security and Privacy Analytics
# 30370 found
# 30371 found
# 30373 found
# 30374 found
# 30376 found
# 30377 found
# 30378 found
# 30380 found
# 30382 found
# 30383 found
# 30384 found
# 30385 found
# 30386 found
# 30387 found 1.0 mla 14 proceedings of the 2014 acm workshop on multimodal learning analytics workshop and grand challenge - Proceedings of the 2014 ACM workshop on Multimodal Learning Analytics Workshop and Grand Challenge
# 30388 found
# 30389 found 1.0 sigmod 14 proceedings of the 2014 acm sigmod international conference on management of data - Proceedings of the 2014 ACM SIGMOD International Conference on Management of Data
# 30390 found 1.0 umap 16 proceedings of the 2016 conference on user modeling adaptation and personalization - Proceedings of the 2016 Conference on User Modeling Adaptation and Personalization
# 30399 found
# 30401 found
# 30402 found
# 30413 found
# 30416 found
# 30418 found
# 30419 found
# 30420 found
# 30421 found
# 30426 found
# 30430 found
# 30433 found
# 30434 found
# 30442 found
# 30446 found
# 30449 found
# 30456 found
# 30458 found
# 30461 found
# 30463 found
# 30464 found
# 30467 found
# 30468 found
# 30469 found
# 30471 found
# 30473 found
# 30476 found
# 30478 found
# 30481 found
# 30484 found
# 30487 found
# 30489 found
# 30490 found
# 30493 found
# 30497 found
# 30498 found
# 30499 found
# 30502 found
# 30506 found
# 30508 found
# 30509 found
# 30511 found
# 30513 found
# 30514 found
# 30515 found
# 30516 found
# 30517 found
# 30518 found
# 30519 found
# 30520 found
# 30523 found
# 30525 found
# 30526 found
# 30528 found
# 30529 found
# 30532 found
# 30533 found
# 30534 found
# 30536 found
# 30538 found
# 30539 found
# 30540 found
# 30542 found
# 30543 found
# 30544 found
# 30546 found
# 30547 found
# 30548 found
# 30549 found
# 30550 found
# 30553 found
# 30554 found
# 30555 found
# 30556 found
# 30557 found
# 30559 found
# 30560 found
# 30562 found
# 30563 found
# 30565 found
# 30566 found
# 30569 found
# 30570 found
# 30577 found
# 30584 found
# 30585 found
# 30610 found 1.0 data science and graduate nursing education a critical literature review - Data Science and Graduate Nursing Education
# 30612 found
# 30617 found
# 30624 found
# 30632 found
# 30647 found 1.0 holding out the promise of lasswells dream big data analytics in public policy research and teachingsicsicsicpalabras clave - Holding out the promise of Lasswell's dream: Big data analytics in public policy research and teaching
# 30652 found
# 30660 found
# 30662 found
# 30668 found
# 30669 found
# 30672 found
# 30679 found
# 30681 found
# 30686 found
# 30687 found
# 30693 found
# 30695 found
# 30703 found
# 30707 found
# 30708 found
# 30713 found
# 30724 found 0.989010989010989 a comparative study of the academic programs between informaticsbiolnformatics and data science in the us - A Comparative Study of the Academic Programs between Informatics/BioInformatics and Data Science in the U.S.
# 30727 found
# 30734 found
# 30738 found
# 30756 found 1.0 designing an introductory course in data science topics and pedagogy - Designing an Introductory Course in Data Science: Topics and Pedagogy (Abstract Only)
# 30761 found
# 30762 found
# 30777 found
# 30780 found
# 30782 found
# 30791 found
# 30797 found
# 30812 found
# 30818 found
# 30824 found
# 30826 found
# 30831 found
# 30834 found
# 30836 found
# 30849 found
# 30852 found
# 30854 found
# 30855 found
# 30859 found
# 30868 found
# 30869 found
# 30877 found
# 30878 found
# 30882 found
# 30884 found
# 30887 found
# 30888 found
# 30889 found
# 30896 found
# 30898 found
# 30902 found
# 30903 found
# 30910 found
# 30915 found
# 30917 found
# 30919 found
# 30924 found
# 30927 found
# 30930 found
# 30932 found
# 30935 found
# 30937 found
# 30939 found
# 30943 found
# 30944 found
# 30945 found
# 30946 found
# 30949 found
# 30951 found
# 30955 found
# 30956 found
# 30958 found
# 30960 found
# 30965 found
# 30967 found
# 30971 found 1.0 uhcsdb ultrahigh carbon steel micrograph database tools for exploring large heterogeneous microstructure datasets - ERRATUM Erratum to : UHCSDB : UltraHigh Carbon Steel Micrograph DataBase Tools for Exploring Large Heterogeneous Microstructure Datasets
# 30972 found
# 30973 found
# 30975 found
# 30978 found
# 30982 found
# 30983 found
# 30985 found
# 30989 found
# 30990 found
# 30991 found
# 30992 found
# 30994 found
# 30998 found
# 31001 found
# 31002 found
# 31003 found
# 31005 found
# 31006 found
# 31008 found
# 31009 found
# 31012 found
# 31018 found
# 31019 found
# 31020 found
# 31021 found
# 31026 found
# 31032 found
# 31036 found
# 31041 found
# 31044 found
# 31045 found
# 31046 found
# 31047 found
# 31051 found
# 31054 found
# 31059 found
# 31065 found
# 31066 found 1.0 the value of industry certifications in ite - The Value of Industry Certifications in ITE: Panel Discussion
# 31078 found
# 31081 found
# 31083 found
# 31085 found
# 31086 found
# 31087 found
# 31088 found
# 31089 found
# 31091 found
# 31092 found
# 31093 found
# 31095 found
# 31096 found
# 31104 found
# 31107 found
# 31108 found
# 31109 found
# 31110 found
# 31111 found
# 31112 found
# 31117 found
# 31119 found
# 31123 found
# 31125 found
# 31131 found
# 31136 found
# 31137 found
# 31139 found
# 31141 found
# 31143 found
# 31147 found
# 31149 found
# 31150 found
# 31153 found
# 31156 found
# 31157 found
# 31158 found
# 31159 found
# 31161 found
# 31163 found
# 31165 found
# 31169 found
# 31174 found
# 31182 found
# 31183 found
# 31184 found
# 31185 found
# 31186 found
# 31187 found
# 31188 found
# 31189 found
# 31190 found
# 31192 found
# 31193 found
# 31194 found
# 31198 found
# 31199 found
# 31200 found
# 31201 found
# 31203 found
# 31205 found
# 31206 found
# 31207 found
# 31209 found
# 31210 found
# 31212 found
# 31214 found 1.0 blockchain for business nextgeneration enterprise artificial intelligence systems - Chapter Five - Blockchain for Business: Next-Generation Enterprise Artificial Intelligence Systems
# 31215 found
# 31216 found
# 31217 found
# 31218 found
# 31219 found
# 31221 found
# 31222 found
# 31224 found
# 31228 found
# 31230 found
# 31231 found
# 31232 found
# 31233 found
# 31234 found
# 31235 found
# 31236 found
# 31241 found
# 31242 found
# 31244 found
# 31246 found
# 31294 found
# 31296 found
# 31299 found
# 31305 found
# 31312 found
# 31314 found
# 31317 found 1.0 models and resources along the data continuum lessons learned in the development and delivery of research data management and data science education - Curricula models and resources along the data continuum: Lessons learned in the development and delivery of research data management and data science education
# 31324 found
# 31325 found 1.0 advancing data science for students of all majors - Advancing Data Science for Students of All Majors (Abstract Only)
# 31326 found
# 31328 found
# 31332 found
# 31339 found
# 31346 found
# 31349 found
# 31352 found
# 31357 found
# 31361 found
# 31362 found
# 31374 found
# 31379 found
# 31380 found
# 31388 found
# 31393 found
# 31394 found
# 31395 found
# 31408 found
# 31409 found
# 31414 found
# 31415 found
# 31426 found 1.0 data science education in secondary schools teaching and learning decision trees with codap and jupyter notebooks as an example of integrating machine - Data science education in secondary schools: teaching and learning decision trees with CODAP and jupyter notebooks as an example of integrating machine learning into statistics education
# 31428 found
# 31432 found
# 31439 found
# 31442 found
# 31444 found
# 31449 found
# 31451 found
# 31458 found
# 31460 found
# 31463 found
# 31464 found 1.0 outlier to normalcy community partnering as a pathway toward modularity sustainability and diversity when centering practicein data science education - From Outlier to Normalcy: Community Partnering as a Pathway Toward Modularity, Sustainability and Diversity When Centering ‘Practice’ in Data Science Education
# 31467 found
# 31468 found
# 31470 found
# 31473 found
# 31475 found
# 31481 found
# 31482 found 1.0 the 5ws and 1h of term projects in the introductory data science classroom - 5Ws AND 1H OF TERM PROJECTS IN THE INTRODUCTORY DATA SCIENCE CLASSROOM
# 31483 found
# 31484 found
# 31487 found 1.0 development of online learning material for data science programming using 3d puzzles - Development of Online Learning Material for Data Science Programming Using 3D Puzzle
# 31488 found
# 31492 found
# 31498 found
# 31499 found
# 31500 found
# 31504 found
# 31507 found
# 31509 found
# 31511 found
# 31512 found
# 31513 found
# 31518 found
# 31519 found
# 31522 found 1.0 big data data science and analytics the opportunity and challenge for is research - Editorial - Big Data, Data Science, and Analytics: The Opportunity and Challenge for IS Research
# 31525 found
# 31529 found
# 31530 found
# 31533 found
# 31540 found
# 31541 found 1.0 a middleschool code camp experience emphasizing data science for social good - A Middle-School Code Camp Experience Emphasizing Data Science for Social Good: (Abstract Only)
# 31545 found 1.0 data science for all an introductory course for nonmajors in flipped format - Data Science for All: An Introductory Course for Non-Majors; in Flipped Format (Abstract Only)
# 31546 found
# 31548 found
# 31551 found
# 31552 found
# 31554 found
# 31556 found
# 31563 found
# 31564 found
# 31570 found
# 31571 found
# 31573 found
# 31574 found
# 31578 found
# 31581 found
# 31582 found 1.0 blockpy interactive demo dual textblock python programming environment for guided practice and data science - BlockPy Interactive Demo: Dual Text/Block Python Programming Environment for Guided Practice and Data Science (Abstract Only)
# 31585 found
# 31618 found
# 31619 found
# 31626 found
# 31628 found 1.0 under the background of data science construct the higher education quality evaluation system of civilianrun regular universities in hubei province based on the - Under the background of data science, construct the higher education quality evaluation system of civilian-run regular universities in Hubei Province based on the Analytic Hierarchy Process (AHP)
# 31633 found
# 31638 found
# 31639 found
# 31649 found
# 31651 found
# 31654 found
# 31658 found
# 31660 found
# 31669 found
# 31670 found 1.0 data science classification and related methods proceedings of the fifth conference of the international federation of classification societies ifcs96 - Data science, classification, and related methods : proceedings of the Fifth Conference of the International Federation of Classification Societies (IFCS-96), Kobe, Japan, March 27-30, 1996
# 31674 found
# 31679 found
# 31680 found 1.0 setting the stage for data science integration of data management skills in introductory and second courses in statistics - Taking a Chance in the Classroom: Setting the Stage for Data Science: Integration of Data Management Skills in Introductory and Second Courses in Statistics
# 31685 found
# 31690 found
# 31698 found
# 31699 found
# 31700 found
# 31701 found
# 31703 found
# 31707 found
# 31709 found
# 31710 found
# 31711 found
# 31714 found
# 31716 found
# 31717 found
# 31725 found
# 31730 found 1.0 advancing data science education through a transdisciplinary conversation - IS EDUCATIONAdvancing data science education through a transdisciplinary conversation
# 31733 found
# 31735 found
# 31739 found 1.0 reproducible research can still be wrong adopting a prevention approach - Opinion: Reproducible research can still be wrong: Adopting a prevention approach
# 31740 found
# 31742 found
# 31744 found
# 31746 found
# 31748 found
# 31755 found
# 31756 found
# 31759 found 1.0 utilizing multifaceted rasch measurement through facets to evaluate science education data sets composed of judges respondents and rating scale items an - Utilizing Multifaceted Rasch Measurement Through FACETS to Evaluate Science Education Data Sets Composed of Judges, Respondents, and Rating Scale Items: An Exemplar Utilizing the Elementary Science Teaching Analysis Matrix Instrument
# 31761 found
# 31763 found
# 31765 found
# 31766 found
# 31771 found
# 31772 found
# 31777 found
# 31785 found
# 31786 found
# 31788 found 1.0 data modeling for undergraduate data science - Data Modeling for Undergraduate Data Science: (Abstract Only)
# 31791 found
# 31792 found
# 31793 found
# 31794 found
# 31795 found
# 31796 found
# 31797 found
# 31798 found 1.0 computer age statistical inference student edition algorithms evidence and data science - Computer Age Statistical Inference, Student Edition
# 31800 found
# 31801 found
# 31802 found
# 31803 found
# 31804 found
# 31813 found 1.0 to the journal of statistics and data science education a call for review of okcupid data for introductory statistics and data science courses by albert - A Letter to the Journal of Statistics and Data Science Education — A Call for Review of “OkCupid Data for Introductory Statistics and Data Science Courses” by Albert Y. Kim and Adriana Escobedo-Land
# 31816 found
# 31829 found
# 31830 found
# 31834 found 1.0 building out data science at small colleges - Building Out Data Science at Small Colleges: (Abstract Only)
# 31836 found
# 31839 found 1.0 research on the construction of data science and big data professional curriculum system based on professional certification concept under the - Research on the Construction of Data Science and Big Data Professional Curriculum System Based on Professional Certification Concept under the Background of New Engineering
# 31841 found 1.0 data science human resourcesconstruction of a foundation for creative human resource development attempts to implement new functions of university education - Efforts of Hokkaido University to Develop Data Science Human Resources -- Construction of a foundation for creative human resource development: attempts to implement new functions of university education
# 31842 found
# 31843 found
# 31844 found
# 31846 found
# 31849 found
# 31850 found
# 31852 found
# 31853 found
# 31856 found
# 31858 found
# 31861 found
# 31864 found
# 31867 found
# 31874 found
# 31875 found
# 31876 found
# 31880 found
# 31881 found
# 31882 found
# 31885 found
# 31886 found 1.0 the sol y agua project enhancing middle school education through computing with an emphasis on simulation and data science - The Sol y Agua Project: Enhancing Middle School Education through Computing with an Emphasis on Simulation and Data Science (Abstract Only)
# 31887 found
# 31888 found
# 31890 found
# 31891 found
# 31896 found
# 31898 found
# 31900 found 1.0 of tertiary education places in advanced digital profiles in the eu focus on artificial intelligence high performance computing cybersecurity and data science - Estimation of supply and demand of tertiary education places in advanced digital profiles in the EU: Focus on Artificial Intelligence, High Performance Computing, Cybersecurity and Data Science
# 31901 found
# 31902 found
# 31905 found 1.0 brainstorming data science as a fluency course for nonmajors and as a new specialization - Brainstorming Data Science as a Fluency Course for Non-Majors and as a New Specialization (Abstract Only)
# 31913 found
# 31914 found
# 31917 found
# 31919 found
# 31922 found
# 31923 found
# 31925 found
# 31926 found
# 31927 found
# 31928 found
# 31930 found
# 31933 found
# 31936 found
# 31937 found 1.0 in designing curriculum for transdisciplinary education on cases of designing concentration on informing science and master program on data science - Challenges in Designing Curriculum for Trans-Disciplinary Education: On Cases of Designing Concentration on Informing Science and Master Program on Data Science
# 31938 found
# 31939 found
# 31941 found
# 31942 found
# 31943 found
# 31945 found
# 31946 found
# 31950 found
# 31953 found
# 31955 found
# 31956 found
# 31957 found
# 31958 found
# 31961 found
# 31962 found
# 31966 found
# 31967 found
# 31968 found
# 31969 found
# 31976 found
# 31979 found
# 31981 found 1.0 data responsibly under the society of critical care medicineeuropean society of intensive care medicine joint data science collaboration the amsterdam - Sharing ICU Patient Data Responsibly Under the Society of Critical Care Medicine/European Society of Intensive Care Medicine Joint Data Science Collaboration: The Amsterdam University Medical Centers Database (AmsterdamUMCdb) Example*
# 31984 found
# 31985 found
# 31986 found
# 31987 found
# 31988 found
# 31991 found
# 31992 found
# 31994 found
# 31997 found
# 32000 found
# 32001 found
# 32002 found
# 32004 found
# 32005 found
# 32007 found
# 32008 found
# 32009 found 1.0 from spreadsheets to programs data science and cs1 in pyret - From Spreadsheets to Programs: Data Science and CS1 in Pyret (Abstract Only)
# 32011 found
# 32014 found
# 32017 found
# 32020 found
# 32022 found
# 32038 found
# 32040 found
# 32048 found
# 32049 found
# 32050 found
# 32051 found
# 32052 found
# 32054 found
# 32056 found 1.0 integrating data science and the internet of things into science technology engineering arts and mathematics education through the use of new and - Integrating Data Science and the Internet of Things Into Science, Technology, Engineering, Arts, and Mathematics Education Through the Use of New and Emerging Technologies
# 32057 found
# 32062 found
# 32063 found
# 32064 found
# 32065 found
# 32069 found
# 32071 found
# 32072 found
# 32073 found 1.0 and homework management with use of github in an introductory crossdisciplinary engineering course series on software engineering and data science - Enrichment Of Student Learning And Homework Management With Use Of GitHub In An Introductory Cross-Disciplinary Engineering Course Series On Software Engineering And Data Science
# 32074 found
# 32075 found
# 32077 found
# 32078 found
# 32079 found
# 32080 found
# 32082 found
# 32083 found
# 32086 found
# 32092 found
# 32094 found
# 32095 found
# 32104 found 1.0 understanding forest health with remote sensing part iii requirements for a scalable multisource forest health monitoring network based on data science - Understanding Forest Health with Remote Sensing, Part III: Requirements for a Scalable Multi-Source Forest Health Monitoring Network Based on Data Science Approaches
# 32106 found
# 32109 found
# 32111 found
# 32112 found
# 32114 found
# 32117 found 1.0 1 grant 2 institutions 3 course variations data science 4 all - 1 Grant + 2 Institutions + 3 Course Variations = Data Science 4 All: (Abstract Only)
# 32118 found
# 32119 found
# 32125 found
# 32127 found
# 32131 found
# 32132 found
# 32133 found
# 32134 found
# 32136 found
# 32137 found
# 32139 found
# 32140 found
# 32142 found
# 32144 found
# 32145 found
# 32147 found
# 32149 found
# 32150 found
# 32151 found
# 32152 found
# 32153 found
# 32154 found
# 32156 found 1.0 univariate bivariate and multivariate statistics using r quantitative tools for data analysis and data science - Univariate, bivariate and multivariate statistics using R: Quantitative tools for data analysis and data scienceDaniel J.Denis2020, Hobokon, NJ, Wiley, ISBN 9781119549932, pp. xvii + 366
# 32160 found
# 32161 found
# 32162 found
# 32163 found
# 32164 found
# 32165 found
# 32169 found
# 32170 found
# 32172 found
# 32175 found
# 32176 found
# 32178 found
# 32180 found
# 32181 found
# 32182 found
# 32189 found
# 32193 found
# 32195 found
# 32196 found
# 32201 found
# 32202 found
# 32203 found
# 32204 found
# 32205 found
# 32207 found
# 32210 found
# 32212 found
# 32213 found
# 32214 found
# 32216 found
# 32219 found
# 32246 found
# 32247 found
# 32248 found
# 32249 found
# 32251 found
# 32252 found
# 32253 found
# 32254 found
# 32256 found
# 32259 found
# 32274 found
# 32280 found
# 32284 found
# 32287 found
# 32291 found
# 32294 found
# 32297 found
# 32301 found 1.0 data science and computing at uc berkeley - Leading Data Science and Computing at UC Berkeley
# 32305 found 1.0 from outlier to normalcy community partnering as a pathway toward modularity sustainability and diversity when centering practicein data science - From Outlier to Normalcy: Community Partnering as a Pathway Toward Modularity, Sustainability and Diversity When Centering ‘Practice’ in Data Science Education
# 32311 found
# 32313 found
# 32314 found
# 32322 found
# 32329 found 1.0 data science careers training and hiring - Data Science Careers, Training, and Hiring: A Comprehensive Guide to the Data Ecosystem: How to Build a Successful Data Science Career, Program, or Unit
# 32331 found
# 32332 found
# 32334 found
# 32335 found 1.0 edison data science framework edsf addressing demand for data science and analytics - EDISON Data Science Framework (EDSF): Addressing Demand for Data Science and Analytics Competences for the Data Driven Digital Economy
# 32336 found
# 32341 found
# 32344 found
# 32346 found
# 32347 found
# 32348 found
# 32351 found
# 32354 found
# 32355 found
# 32356 found
# 32357 found
# 32359 found
# 32360 found
# 32361 found
# 32364 found
# 32366 found
# 32372 found
# 32373 found
# 32382 found
# 32383 found
# 32389 found
# 32390 found
# 32397 found
# 32398 found
# 32403 found
# 32404 found
# 32406 found
# 32409 found
# 32421 found
# 32425 found
# 32428 found
# 32429 found
# 32431 found
# 32436 found
# 32437 found
# 32448 found
# 32449 found 1.0 interleaving computational and inferential thinking data science for undergraduates at - Interleaving Computational and Inferential Thinking: Data Science for Undergraduates at Berkeley
# 32452 found
# 32455 found
# 32463 found
# 32465 found
# 32469 found
# 32470 found
# 32474 found
# 32475 found 1.0 revisiting statistical analysis curriculum in a data era a learningbymistake approach - Delft University of Technology Revisiting statistical analysis curriculum in a data era: a learning-by-mistake approach
# 32477 found
# 32481 found
# 32490 found
# 32491 found
# 32492 found
# 32493 found
# 32497 found 1.0 integrating data science ethics into an undergraduate major - Integrating Data Science Ethics Into an Undergraduate Major: A Case Study
# 32501 found
# 32503 found
# 32504 found
# 32506 found
# 32508 found
# 32510 found
# 32514 found
# 32518 found
# 32519 found
# 32524 found
# 32526 found
# 32528 found
# 32530 found
# 32532 found 1.0 its all in the mix a new interprofessional blendedlearning masters program for biomedical data science addressing physicians and students from life sciences - It's All in the Mix: A New Interprofessional, Blended-Learning Masters' Program for Biomedical Data Science Addressing Physicians and Students from Life Sciences - Didactic Concept and First Experiences
# 32534 found
# 32538 found
# 32539 found
# 32545 found
# 32547 found
# 32548 found
# 32549 found
# 32552 found
# 32555 found
# 32559 found
# 32563 found
# 32564 found
# 32568 found
# 32569 found
# 32571 found
# 32578 found
# 32579 found
# 32580 found
# 32581 found
# 32583 found
# 32584 found
# 32586 found
# 32587 found 1.0 using an undergraduate decision science course to prepare business students for the later study of data science and - USING AN UNDERGRADUATE DECISION SCIENCE COURSE TO PREPARE BUSINESS STUDENTS FOR THE LATER STUDY OF DATA SCIENCE AND ANALYTICS
# 32590 found
# 32594 found
# 32595 found
# 32597 found
# 32598 found
# 32599 found
# 32601 found
# 32605 found
# 32606 found
# 32608 found
# 32613 found
# 32616 found
# 32618 found
# 32620 found
# 32623 found
# 32627 found
# 32628 found
# 32630 found
# 32632 found
# 32633 found
# 32634 found
# 32635 found
# 32637 found
# 32651 found
# 32652 found
# 32656 found
# 32658 found 1.0 big data and fair data for data science - Chapter 6 Big Data and FAIR Data for Data Science
# 32659 found
# 32662 found
# 32664 found
# 32668 found
# 32669 found
# 32673 found
# 32675 found
# 32680 found
# 32684 found
# 32686 found
# 32687 found 1.0 development of the intelligence and machine learning tame toolkit for introductory data science chemicalbiological analyses predictive modeling - Development of the InTelligence And Machine LEarning (TAME) Toolkit for Introductory Data Science, Chemical-Biological Analyses, Predictive Modeling, and Database Mining for Environmental Health Research
# 32688 found
# 32691 found
# 32692 found
# 32696 found
# 32700 found
# 32701 found
# 32702 found
# 32703 found
# 32704 found
# 32707 found 1.0 the curriculum and community enterprise for restoration science engaging marginalized students in stem fields through data acquisition and computational - The Curriculum and Community Enterprise for Restoration Science: Engaging Marginalized Students in STEM Fields through Data Acquisition and Computational Thinking
# 32708 found
# 32712 found
# 32716 found
# 32717 found
# 32719 found
# 32722 found
# 32727 found
# 32728 found
# 32734 found
# 32736 found
# 32742 found
# 32746 found
# 32748 found
# 32750 found
# 32752 found
# 32753 found
# 32754 found
# 32759 found
# 32760 found
# 32762 found
# 32763 found
# 32764 found
# 32765 found
# 32768 found
# 32774 found
# 32775 found
# 32777 found
# 32779 found
# 32780 found
# 32784 found
# 32785 found
# 32787 found
# 32790 found
# 32791 found
# 32798 found
# 32799 found
# 32803 found
# 32806 found
# 32807 found
# 32812 found
# 32814 found
# 32816 found
# 32817 found
# 32821 found
# 32822 found
# 32826 found
# 32830 found
# 32831 found
# 32833 found
# 32835 found
# 32837 found
# 32838 found
# 32839 found
# 32840 found
# 32841 found 1.0 faculty moving to data science from other disciplines - Changing Paradigms: Faculty Moving to Data Science from Other Disciplines
# 32845 found
# 32847 found 1.0 data science sous python algorithme statistique dataviz datamining et machinelearning data science with python algorithm statistics dataviz datamining - Data Science sous Python: Algorithme, Statistique, DataViz, DataMining et Machine-Learning
# 32851 found
# 32856 found
# 32860 found
# 32861 found
# 32862 found
# 32864 found
# 32865 found
# 32869 found
# 32873 found
# 32876 found
# 32878 found
# 32881 found
# 32882 found
# 32883 found
# 32885 found
# 32886 found
# 32889 found
# 32893 found
# 32895 found
# 32898 found
# 32899 found
# 32900 found
# 32904 found
# 32908 found
# 32910 found
# 32911 found
# 32915 found
# 32916 found 1.0 cross reality and data science in engineering proceedings of the 17th international conference on remote engineering and virtual instrumentation - Cross Reality and Data Science in Engineering - Proceedings of the 17th International Conference on Remote Engineering and Virtual Instrumentation, REV 2020, Athens, GA, USA, 26-28 February, 2020
# 32917 found
# 32920 found 1.0 multimodal learning analysis of the application of data science in the research of investment psychology and behavior - MULTIMODAL LEARNING ANALYSIS OF THE APPLICATION OF DATA SCIENCE IN THE RESEARCH OF INVESTMENT PSYCHOLOGY AND BEHAVIOR UNDER COGNITIVE IMPAIRMENT
# 32924 found
# 32927 found
# 32932 found
# 32933 found
# 32934 found
# 32935 found
# 32936 found
# 32937 found
# 32938 found
# 32942 found
# 32947 found 1.0 tools technologies and methodologies to support data science support technologies for data science - Tools, Technologies, and Methodologies to Support Data Science
# 32948 found
# 32949 found
# 32953 found
# 32954 found
# 32955 found
# 32957 found
# 32959 found
# 32960 found
# 32962 found
# 32965 found
# 32967 found
# 32968 found
# 32969 found
# 32970 found
# 32971 found
# 32974 found
# 32979 found 1.0 data science rd current activities future directions - EliScholar – A Digital Platform for Scholarly Publishing at Yale Data Science R&D: Current Activities, Future Directions
# 32980 found
# 32982 found
# 32986 found
# 32988 found
# 32992 found
# 32993 found
# 32994 found
# 33001 found
# 33003 found
# 33004 found
# 33005 found
# 33012 found
# 33017 found
# 33019 found
# 33021 found
# 33024 found
# 33025 found
# 33030 found 1.0 chapter three toward collaborative open data science in metabolomics using jupyter notebooks and cloud computing - Toward collaborative open data science in metabolomics using Jupyter Notebooks and cloud computing
# 33036 found
# 33037 found
# 33039 found
# 33041 found
# 33042 found
# 33043 found 1.0 the craft and coordination of data curation complicating workflow views of data science preprint - The Craft and Coordination of Data Curation: Complicating Workflow Views of Data Science
# 33044 found
# 33045 found
# 33050 found
# 33051 found
# 33053 found
# 33055 found
# 33056 found
# 33059 found
# 33066 found
# 33070 found
# 33072 found
# 33073 found 1.0 the effect of teaching reform path of vocal music course in colleges and universities on studentscognitive ability from - THE EFFECT OF TEACHING REFORM PATH OF VOCAL MUSIC COURSE IN COLLEGES AND UNIVERSITIES ON STUDENTS ’ COGNITIVE ABILITY FROM THE PERSPECTIVE OF EDUCATIONAL PSYCHOLOGY
# 33074 found
# 33075 found
# 33076 found 1.0 alcomputing schizophrenia ethical challenges for machine learning in psychiatry from machine learning to student learning pedagogical challenges for psychiatry - Comment on Starke et al.: 'Computing schizophrenia: ethical challenges for machine learning in psychiatry': from machine learning to student learning: pedagogical challenges for psychiatry.
# 33079 found
# 33080 found
# 33081 found
# 33082 found
# 33087 found
# 33088 found
# 33091 found
# 33095 found
# 33097 found
# 33098 found
# 33100 found
# 33101 found
# 33102 found 1.0 competency based and technologically enhanced teaching and learning collaborative virtual environment and tuning - COMPETENCY BASED AND TECHNOLOGICALLY ENHANCED TEACHING AND LEARNING: COLLABORATIVE VIRTUAL ENVIRONMENT AND TUNING METHODOLOGY
# 33104 found
# 33105 found
# 33106 found
# 33108 found
# 33111 found
# 33112 found
# 33117 found
# 33120 found
# 33121 found
# 33122 found
# 33123 found
# 33124 found
# 33126 found
# 33128 found
# 33129 found
# 33131 found
# 33132 found
# 33133 found
# 33139 found
# 33140 found
# 33142 found
# 33143 found
# 33145 found
# 33146 found
# 33149 found
# 33150 found
# 33151 found
# 33155 found
# 33158 found
# 33159 found
# 33160 found
# 33163 found
# 33164 found
# 33170 found
# 33172 found
# 33176 found
# 33178 found
# 33179 found
# 33180 found
# 33181 found
# 33182 found
# 33183 found
# 33184 found
# 33185 found
# 33188 found
# 33189 found
# 33192 found
# 33193 found
# 33194 found 1.0 knowledge discovery in big data from astronomy and earth observation astrogeoinformatics - Knowledge Discovery in Big Data from Astronomy and Earth Observation
# 33195 found
# 33196 found
# 33201 found
# 33202 found
# 33205 found
# 33206 found
# 33207 found
# 33209 found
# 33211 found
# 33212 found
# 33213 found
# 33214 found
# 33216 found
# 33219 found
# 33221 found
# 33223 found
# 33224 found
# 33225 found
# 33226 found
# 33227 found
# 33230 found
# 33231 found
# 33232 found
# 33233 found
# 33234 found
# 33237 found
# 33238 found 1.0 the emergence ofcomputer science and law the new legal paradigm for law and policy practice in the computational age of algorithmic reasoning and big - The Emergence of 'Computer Science and Law': The New Legal Paradigm for Law and Policy Practice in the Computational Age of Algorithmic Reasoning and Big Data Practice
# 33242 found
# 33244 found
# 33247 found
# 33249 found
# 33252 found
# 33253 found
# 33255 found
# 33263 found
# 33264 found
# 33265 found
# 33266 found
# 33270 found
# 33272 found
# 33274 found
# 33279 found
# 33280 found
# 33284 found
# 33288 found
# 33289 found
# 33291 found 1.0 effect of reentry policy implementation on readmitted girls academic performance in mathematics in selected secondary schools of mufulira district in - Effect of Re-entry Policy Implementation on Readmitted Girls’ Academic Performance in Mathematics in Selected Secondary Schools of Mufulira District in Zambia
# 33293 found
# 33296 found
# 33298 found
# 33303 found
# 33305 found
# 33307 found
# 33314 found
# 33315 found
# 33318 found
# 33320 found
# 33321 found
# 33323 found
# 33326 found 1.0 paradigms a case study on scientists perceptions about contemporary metaorganism science and implications for science environment health pedagogy - Communicating New Scientific Paradigms: A Case Study on Scientists’ Perceptions About Contemporary Metaorganism Science and Implications for Science|Environment|Health Pedagogy
# 33328 found
# 33329 found
# 33330 found
# 33331 found
# 33333 found
# 33334 found
# 33335 found
# 33336 found
# 33337 found
# 33338 found
# 33341 found
# 33342 found
# 33343 found
# 33344 found
# 33345 found
# 33346 found
# 33349 found
# 33351 found
# 33353 found
# 33354 found
# 33355 found
# 33360 found
# 33361 found
# 33363 found
# 33364 found
# 33365 found
# 33367 found
# 33369 found
# 33372 found
# 33374 found 1.0 basketball data science with applications in r - Paola Zuccolotto and Marica Manisera (2020): Basketball Data Science: With Applications in R, CRC Press, 243 pp., £80.50 (Hardcover), ISBN: 978-1-138-60079-9
# 33379 found
# 33381 found
# 33383 found
# 33385 found
# 33386 found
# 33387 found
# 33388 found
# 33390 found
# 33391 found
# 33392 found
# 33393 found
# 33395 found
# 33397 found
# 33398 found
# 33399 found
# 33403 found
# 33404 found
# 33405 found
# 33407 found
# 33408 found
# 33412 found
# 33413 found
# 33415 found
# 33416 found
# 33419 found
# 33420 found
# 33421 found
# 33422 found
# 33426 found
# 33427 found
# 33428 found 1.0 multisensorfusion approach for a datascienceoriented preventive health management system concept and development of a decentralized data collection - Multi-Sensor-Fusion Approach for a Data-Science-Oriented Preventive Health Management System: Concept and Development of a Decentralized Data Collection Approach for Heterogeneous Data Sources
# 33430 found
# 33431 found
# 33432 found
# 33434 found
# 33437 found
# 33445 found
# 33446 found
# 33447 found
# 33448 found
# 33450 found
# 33451 found
# 33453 found
# 33455 found
# 33456 found
# 33461 found
# 33462 found
# 33463 found
# 33465 found
# 33466 found
# 33467 found
# 33468 found 1.0 data science for business what you need to know about data mining and data analytic thinking provost foster fawcett tom - Data Science for Business: What You Need to Know about Data Mining and Data-Analytic Thinking
# 33469 found
# 33470 found
# 33474 found
# 33476 found
# 33477 found
# 33481 found
# 33482 found
# 33484 found
# 33485 found
# 33487 found
# 33488 found
# 33489 found
# 33490 found
# 33491 found
# 33492 found
# 33493 found
# 33496 found
# 33497 found
# 33499 found 1.0 docdoc preparing for the utilization of data sciencedata analytics in earth science research - Preparing for the Utilization of Data Science / Data Analytics in Earth Science Research
# 33501 found
# 33502 found
# 33503 found
# 33505 found
# 33506 found
# 33512 found
# 33514 found 1.0 introduction to data science for social and policy research - Introduction to Data Science for Social and Policy Research: Collecting and Organizing Data with R and Python
# 33516 found
# 33518 found
# 33519 found
# 33520 found 1.0 a new era of inorganic materials discovery powered by data science - Chapter 13. A New Era of Inorganic Materials Discovery Powered by Data Science
# 33522 found
# 33525 found
# 33528 found
# 33530 found
# 33532 found
# 33535 found
# 33536 found
# 33539 found
# 33542 found
# 33543 found
# 33544 found
# 33545 found
# 33546 found
# 33547 found
# 33548 found 1.0 what managers need to know about big data an interview with foster provost - What Managers Need to Know About Big Data
# 33549 found
# 33551 found
# 33555 found
# 33556 found
# 33557 found
# 33558 found
# 33560 found
# 33561 found 1.0 mere renovation is too little too late we need to rethink our undergraduate curriculum from the ground up cobb 2015 - Mere Renovation is Too Little Too Late: We Need to Rethink our Undergraduate Curriculum from the Ground Up
# 33562 found
# 33563 found
# 33564 found
# 33567 found
# 33569 found
# 33570 found
# 33571 found
# 33572 found
# 33573 found 1.0 the relationships among high school students epistemological views on theory and data science process skills perceptions of preferred laboratory learning - The Relationships among High School Students' Epistemological Views on Theory and Data, Science Process Skills, Perceptions of Preferred Laboratory Learning Environment and Attitudes toward Laboratory Work
# 33575 found
# 33576 found 1.0 technical report on the usability of hadoop mapreduce apache spark apache flink for data science - On the usability of Hadoop MapReduce, Apache Spark & Apache flink for data science
# 33577 found
# 33579 found
# 33581 found
# 33583 found
# 33584 found
# 33585 found
# 33589 found
# 33590 found
# 33593 found
# 33596 found
# 33597 found
# 33598 found
# 33599 found
# 33600 found
# 33601 found
# 33602 found
# 33603 found
# 33606 found
# 33610 found
# 33611 found
# 33613 found
# 33614 found
# 33615 found
# 33617 found
# 33619 found 1.0 practical data science with python 3 - Practical Data Science with Python 3: Synthesizing Actionable Insights from Data
# 33620 found
# 33623 found
# 33624 found
# 33626 found
# 33628 found
# 33629 found
# 33631 found
# 33633 found 1.0 free and open source software in modern data science and business intelligence emerging research and opportunities emerging research and opportunities - Free and Open Source Software in Modern Data Science and Business Intelligence: Emerging Research and Opportunities
# 33635 found 1.0 importance of prior knowledge and the nature of the science content for understanding elementary students comprehension of informational and data science - Towards a more complex view of genre: The importance of prior knowledge and the nature of the science content for understanding elementary students' comprehension of informational and data science texts
# 33638 found
# 33640 found
# 33642 found
# 33645 found
# 33646 found
# 33648 found
# 33650 found
# 33651 found
# 33652 found
# 33653 found
# 33654 found
# 33655 found
# 33660 found
# 33661 found
# 33662 found
# 33663 found
# 33665 found
# 33668 found
# 33670 found
# 33671 found
# 33672 found
# 33673 found
# 33674 found
# 33675 found
# 33678 found
# 33679 found
# 33682 found
# 33684 found 1.0 teaching an introductory programming course to noncomputer science majors using sagemath - Teaching an Introductory Programming Course to NonComputer Science Majors Using
# 33689 found
# 33691 found
# 33693 found
# 33695 found
# 33696 found
# 33699 found
# 33701 found
# 33703 found
# 33704 found
# 33705 found
# 33706 found
# 33708 found
# 33710 found
# 33711 found
# 33713 found
# 33715 found

# %% [markdown]
# # Verify that the search terms are found in title of in abstract

# %%
row_queries.dropna(subset=['paperId','title','abstract'],inplace=True)
row_queries.shape[0]
# Out:
# 26956

# %%
def key_words_found(s):
  return ('data science' in s) and any([x in s for x in ['education','curriculum','pedagogy','teach']])

row_queries = row_queries[row_queries['title'].str.lower().apply(key_words_found) | row_queries['abstract'].str.lower().apply(key_words_found)]
print('Papers with valid title and abstract:',row_queries.shape[0])
# Out:
# Papers with valid title and abstract: 1073

# %%
pd.to_excel('DSE Semantic scholar ids.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-12d1941e1e57> in <cell line: 1>()
# ----> 1 pd.to_excel('DSE Semantic scholar ids.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'to_excel'
